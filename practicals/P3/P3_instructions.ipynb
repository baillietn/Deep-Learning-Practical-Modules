# %% [markdown]
# # Practical session n°3
#
# Notions:
# - Training from scratch
# - Validation step
# - Learning curves
# - Pretraining / Fine tuning
# - Data augmentation (DAUG)
# - Freezing
#
# Duration: 1 h 30
#
# Now that we have covered the basic building blocks, we will train a Convolutional Neural Network (CNN) on slightly more challenging problems than separation of points in a 2D space:
# - handwritten digit recognition (part **I.**)
# - binary classification of photos (part **II.**)
#
# The first machine learning problem will give us the opportunity to train a tiny CNN from scratch through a complete training loop (including training and validation steps).
# An efficient training from scratch on the second problem would need much more images than the few available photos (200). We hence use one of the most interesting features of the neural networks: once trained on a very big dataset on a very general task, they could be "retrained" (one says fine tuned) on a very specific task that share the same inputs. As such pretrained neural network are much bigger than our first tiny CNN, a graphics card will be used to significantly speed up the process.

# %% [markdown]
# ### **I.A.** The MNIST Database of Handwritten Digit

# %% [markdown]
# The Database of Handwritten Digit of the NIST (National Institute of Standards and Technologogies) comprises 70,000 black and white  images of handwritten digits of 28x28 pixels. A specific dataset object is allocated to it in the torchvision.datasets module. \
# The subsequent cells are designed to import packages, download the MNIST database, define dataLoaders and showcase some images.

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torchvision import datasets, models, transforms

# %%
# transforms (format/normalization)
tr=torchvision.transforms.Compose([
   torchvision.transforms.ToTensor(),
   torchvision.transforms.Normalize((0.1307,), (0.3081,))
   ])

# Definition of training sets:
trainval_dataset = datasets.MNIST(root='./data',
                                  train=True,
                                  download=True,
                                  transform=tr)

# Split indices for training and validation
num_images = len(trainval_dataset)
indices = list(range(num_images))
split = int(np.floor(0.2 * num_images))  # 20% validation

# Shuffle indices
np.random.seed(42)  # Seed for reproducibility
np.random.shuffle(indices)

# Create train and validation samplers
train_indices, val_indices = indices[split:], indices[:split]

from torch.utils.data import SubsetRandomSampler
train_sampler = SubsetRandomSampler(train_indices)
val_sampler = SubsetRandomSampler(val_indices)
train_size = len(train_sampler)
val_size = len(val_sampler)

# Definition of the train/val loaders
bs = 8
num_workers = 2 # try : print(os.cpu_count())

train_loader = DataLoader(trainval_dataset, batch_size=bs,
                          sampler=train_sampler, num_workers=num_workers)
val_loader = DataLoader(trainval_dataset, batch_size=bs,
                        sampler=val_sampler, num_workers=num_workers)
# Out:
# 100%|██████████| 9.91M/9.91M [00:01<00:00, 8.05MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 354kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 2.01MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 23.6MB/s]

# %%
x, t = next(iter(train_loader))

print(x.shape)

fig = plt.figure()
for i in range(8):
  plt.subplot(4,2,i+1)
  plt.tight_layout()
  plt.imshow(x[i,0,:,:], cmap='gray') #, interpolation='none')
  plt.title("Ground Truth: {}".format(t[i]))
  plt.xticks([])
  plt.yticks([])
# Out:
# torch.Size([8, 1, 28, 28])

# %% [markdown]
# **Exercise 1**:
# - Are images sampled by train_loader and val_loader normalized?
# - How much images are in *train_loader* and *val_loader*?
# - What will be the role of the validation loader?

# %% [markdown]
# ### **I.B.** A vanilla CNN

# %% [markdown]
# Now, we will define a vanilla CNN with two convolution layers.
#
# **Exercise 2:**  Determine *N* in such a way that the network can accept MNIST images as input.
# How outputs will be interpreted after the training ?

# %%
# N = 28*28 / (2*2) / (2*2) * 10 = 7*7*10 = 490

N = 490

class CNN(nn.Module):

    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5, padding=2)
        self.conv2 = nn.Conv2d(10, 10, kernel_size=5, padding=2)
        self.fc1 = nn.Linear(N, 50)
        self.fc2 = nn.Linear(50, 10)

    def forward(self, x):
        x = F.relu(F.max_pool2d(self.conv1(x), 2))
        x = F.relu(F.max_pool2d(self.conv2(x), 2))

        # convert an image to a 1D torch.tensor:
        x = x.view(-1, N)
        x = F.relu(self.fc1(x))
        x = F.dropout(x, training=self.training)
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)

# %% [markdown]
# ### **I.C.** Training of the CNN

# %% [markdown]
# To train a CNN, let's define a loss function. Since the log of output probabilities has been computed with *F.log_softmax*, we only need to gather the logits associated with the target classes. This can be done with the torch.gather function (see **P1**), but the standard way in PyTorch is to use *torch.nn.NLLLoss()*.

# %%
model = CNN()

#optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum = 0.9)
optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)

# NLLLoss() will have the same effect as torch.gather (see TP1)
loss_fn =  torch.nn.NLLLoss()

# %% [markdown]
# A complete training loop has (at least) two phases: weights are updated only in the first phase dedicated to training. During the validation phase, **generalization performance** on independent images is monitored.

# %% [markdown]
# **Exercise 3**:
# Complete the following code to print the mean loss and the accuracy on the train and validation sets.

# %%
import time

num_epochs = 2

# Initialize time
start_time = time.time()

# Learning Loop:
for epoch in range(num_epochs):
    print(f'Epoch: {epoch}')

    running_loss_train = 0.0
    running_corrects_train = 0
    running_loss_val = 0.0
    running_corrects_val = 0

    # Phase 1: Training
    model.train()  # Set the model to training mode
    for x, label in train_loader:
        optimizer.zero_grad()
        output = model(x)
        loss = loss_fn(output, label)
        loss.backward()
        optimizer.step()

        # Get predicted classes:
        _, preds = torch.max(output, 1)

        # Update counters:
        running_loss_train += loss.item() * x.shape[0]
        running_corrects_train += torch.sum(preds == label.data)

    # Calculate training scores (todo):
    epoch_loss_train = running_loss_train / train_size
    epoch_acc_train = running_corrects_train.float() / train_size

    print(f'Train Loss: {epoch_loss_train:.4f} Acc: {epoch_acc_train:.4f}')

    # Phase 2: Validation
    model.eval()  # Set the model to evaluation mode
    with torch.no_grad():
        for x, label in val_loader:
            output = model(x)
            loss = loss_fn(output, label)

            # Get predicted classes:
            _, preds = torch.max(output, 1)

            # Update counters:
            running_loss_val += loss.item() * x.shape[0]
            running_corrects_val += torch.sum(preds == label.data)

    # Calculate validation scores (todo):
    epoch_loss_val = running_loss_val / val_size
    epoch_acc_val = running_corrects_val.float() / val_size

    print(f'Validation Loss: {epoch_loss_val:.4f} Acc: {epoch_acc_val:.4f}')

    # Print elapsed time:
    elapsed_time = time.time() - start_time
    print(f'Time: {round(elapsed_time)} seconds')

    # Update start time for the next epoch
    start_time = time.time()
# Out:
# Epoch: 0
# Train Loss: 0.3967 Acc: 0.8675
# Validation Loss: 0.0851 Acc: 0.9752
# Time: 11 seconds
# Epoch: 1
# Train Loss: 0.1944 Acc: 0.9373
# Validation Loss: 0.0609 Acc: 0.9822
# Time: 11 seconds

# %%
train_losses = []
val_losses = []

train_accs = []
val_accs = []

### BEGIN SOLUTION

# Initialize time
start_time = time.time()

# Learning Loop:
for epoch in range(6):
    print('epoch :' + str(epoch))

    running_loss_train = 0.
    running_corrects_train = 0.
    running_loss_val = 0.
    running_corrects_val = 0.

    # Training
    for x, label in train_loader:
        optimizer.zero_grad()
        output = model(x)
        l = loss_fn(output, label)
        l.backward()
        optimizer.step()

        # Get predicted classes:
        _, preds = torch.max(output, 1)

        # Counters:
        running_loss_train += l.item() * x.shape[0]
        running_corrects_train += torch.sum(preds == label.data)

    # Calculate training scores and store:
    epoch_loss_train = running_loss_train / train_size
    epoch_acc_train = running_corrects_train.float() / train_size
    train_losses.append(epoch_loss_train)
    train_accs.append(epoch_acc_train)

    print('{} Loss: {:.4f} Acc: {:.4f}'.format(
        'train', epoch_loss_train, epoch_acc_train))


    # validation
    model.eval()

    for x, label in val_loader:

        with torch.no_grad():
            output = model(x)
            l = loss_fn(output, label)

        # Get predicted classes:
        _, preds = torch.max(output, 1)

        # Counters:
        running_loss_val += l.item() * x.shape[0]
        running_corrects_val += torch.sum(preds == label.data)

    # Calculate training scores and store:
    epoch_loss_val = running_loss_val / val_size
    epoch_acc_val = running_corrects_val.float() / val_size
    val_losses.append(epoch_loss_val)
    val_accs.append(epoch_acc_val)


    print('{} Loss: {:.4f} Acc: {:.4f}'.format(
        'val', epoch_loss_val, epoch_acc_val))

    # Print elapsed time:
    elapsed_time = time.time() - start_time
    print(f'Time: {round(elapsed_time)} seconds')


### END SOLUTION
# Out:
# epoch :0
# train Loss: 0.0495 Acc: 0.9847
# val Loss: 0.0527 Acc: 0.9856
# Time: 11 seconds
# epoch :1
# train Loss: 0.0397 Acc: 0.9884
# val Loss: 0.0484 Acc: 0.9868
# Time: 21 seconds
# epoch :2
# train Loss: 0.0315 Acc: 0.9902
# val Loss: 0.0470 Acc: 0.9865
# Time: 32 seconds
# epoch :3
# train Loss: 0.0262 Acc: 0.9917
# val Loss: 0.0741 Acc: 0.9833
# Time: 42 seconds
# epoch :4
# train Loss: 0.0256 Acc: 0.9921
# val Loss: 0.0632 Acc: 0.9862
# Time: 53 seconds
# epoch :5
# train Loss: 0.0218 Acc: 0.9929
# val Loss: 0.0633 Acc: 0.9868
# Time: 64 seconds

# %% [markdown]
# **Exercise 4**:
# At each epoch, store the accuracy and the cost function value in the lists *train_losses*, *val_losses*, *train_accs*, and *val_accs*.
# Plot the **learning curves** over six epochs.

# %%
fig, ax = plt.subplots()
plt.title('evolution of training and validation accuracies')

ax.plot(np.arange(len(train_accs)), train_accs, color = 'r')
ax.plot(np.arange(len(val_accs)), val_accs, color = 'b')
ax.legend(['train acc.', 'val acc.'])

# %%
fig2, ax2 = plt.subplots()
plt.title('loss = f(epoch)')
ax2.plot(np.arange(len(train_losses)), train_losses,  color = 'r')
ax2.plot(np.arange(len(val_losses)), val_losses, color = 'b')
ax2.legend(['train losses', 'val losses'])

# %% [markdown]
# **Exercise 5:** Complete the following perceptron (P60) to directly take MNIST images as input.
# Compare the standalone perceptron to the CNN in terms of size (number of weights) and performance on a test set.

# %%
class P60(nn.Module):

    def __init__(self):
        super(P60, self).__init__()
        self.fc1 = nn.Linear(28*28, 50)
        self.fc2 = nn.Linear(50, 10)

    def forward(self, x):
        # flattening x
        x = x.view(-1, 28*28)

        # apply first layer
        x = F.relu(self.fc1(x))

        # apply second layer
        x = F.dropout(x, training=self.training)
        x = self.fc2(x)
        x = F.log_softmax(x, dim=1)
        return x

perceptron = P60()
optimizer = torch.optim.Adam(perceptron.parameters(), lr = 0.001)
loss_fn =  torch.nn.NLLLoss()

# %%
# Size comparison:

# Count parameters for CNN
cnn_params = sum(p.numel() for p in model.parameters())
print(f"CNN total parameters: {cnn_params}")

# Count parameters for P60
p60_params = sum(p.numel() for p in perceptron.parameters())
print(f"P60 total parameters: {p60_params}")
# Out:
# CNN total parameters: 27830
# P60 total parameters: 39760

# %%
# Performance comparison (on the validation set):

# Evaluate CNN on validation set
model.eval()
cnn_correct = 0
with torch.no_grad():
    for x, label in val_loader:
        output = model(x)
        _, preds = torch.max(output, 1)
        cnn_correct += torch.sum(preds == label.data)

cnn_acc = cnn_correct.float() / val_size
print(f"CNN validation accuracy: {cnn_acc:.4f}")

# Evaluate P60 on validation set
perceptron.eval()
p60_correct = 0
with torch.no_grad():
    for x, label in val_loader:
        output = perceptron(x)
        _, preds = torch.max(output, 1)
        p60_correct += torch.sum(preds == label.data)

p60_acc = p60_correct.float() / val_size
print(f"P60 validation accuracy: {p60_acc:.4f}")
# Out:
# CNN validation accuracy: 0.9868
# P60 validation accuracy: 0.1084

# %% [markdown]
# ### **II.A.** Load and viz the Hymenoptera dataset:

# %% [markdown]
# Through a second image classification problem, we focus on two other important aspects of deep learning: speeding up the learning with GPU cards and the ability to use pretrained networks.
#
# To illustrate the first aspect, we will use the GPUs available under Google Colab. To do this, before starting this part, go to **Modifier**/**Modifier les param du notebook** and select a GPU.

# %%
# Check GPU availability
if torch.cuda.is_available():
  device = torch.device("cuda:0") # 0 is the index of the GPU
  print(torch.cuda.get_device_name(device))
else:
  print('Change the runtime type to GPU')
# Out:
# NVIDIA GeForce RTX 5070 Ti Laptop GPU

# %% [markdown]
# Now let's download inputs (RGB images of bees or ants) and targets ("bee" or "ant").

# %%
# download the dataset
! wget https://download.pytorch.org/tutorial/hymenoptera_data.zip
! unzip -qq hymenoptera_data.zip
# Out:
# --2026-03-28 00:48:03--  https://download.pytorch.org/tutorial/hymenoptera_data.zip
# Resolving download.pytorch.org (download.pytorch.org)... 2600:9000:21f7:9e00:d:607e:4540:93a1, 2600:9000:21f7:ea00:d:607e:4540:93a1, 2600:9000:21f7:d600:d:607e:4540:93a1, ...
# Connecting to download.pytorch.org (download.pytorch.org)|2600:9000:21f7:9e00:d:607e:4540:93a1|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 47286322 (45M) [application/zip]
# Saving to: ‘hymenoptera_data.zip’
#
# hymenoptera_data.zi 100%[===================>]  45.10M   150MB/s    in 0.3s
#
# 2026-03-28 00:48:04 (150 MB/s) - ‘hymenoptera_data.zip’ saved [47286322/47286322]

# %%
dir_data = 'hymenoptera_data'
print(os.listdir(dir_data))
# Out:
# ['val', 'train']

# %% [markdown]
# The dataset is in a standard format, and we can manipulate it with a ready-to-use dataset object of the datasets.ImageFolder class:

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        #transforms.RandomVerticalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

image_datasets = {x: datasets.ImageFolder(os.path.join(dir_data, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}

dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=4,
                                             shuffle=True, num_workers=0)
              for x in ['train', 'val']}

dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}

print('Dataset sizs:' )
print(dataset_sizes)
# Out:
# Dataset sizs:
# {'train': 244, 'val': 153}

# %% [markdown]
# Since the provided dataset is very small, we need to maximize its utility. We will produce new images through additional transformations that preserve the nature of the object (data augmentation). \
# In the code, transforms.*RandomResizedCrop()*, *transforms.RandomHorizontalFlip()* and *transforms.RandomVerticalFlip()* apply horizontal or vertical axis symmetry with a probability of 1/2. Note that these transformations might not be suitable for other datasets like MNIST since the mirror image of a digit is generally not another digit. \
# Some images are presented below.

# %%
def imshow(inp, ax=None, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    if ax is None:
      plt.imshow(inp)
      plt.title(title)
    else:
      ax.imshow(inp)
      ax.set_title(title)

# %%
def plot_batch(images, labels, class_names):
    num_images = len(images)
    fig, axs = plt.subplots(1, num_images, figsize=(15, 5))

    for i in range(num_images):
        axs[i].axis('off')
        imshow(images[i],axs[i],class_names[labels[i]])
    plt.show()

# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))
class_names = image_datasets['train'].classes
# Assuming `inputs` is a batch of images and `classes` are the corresponding class labels
plot_batch(inputs, classes, class_names)

# %% [markdown]
# ### **II.B.** Adaptation of a ResNet18 architecture:
#
# In this part, the lightest of the ResNet architectures is adapted to our binary classification problem and trained over one epoch.

# %% [markdown]
# **Exercise 6:**
#
# - Load an untrained ResNet18. How many total weights does it contain? Check [here](https://pytorch.org/vision/main/models/generated/torchvision.models.resnet18.html).
#
# - How many neurons does the last layer of the network have?
#
# - Is there a softmax operation at the end of *ResNet.forward()*?
#
# - Modify the last layer of the classifier so that it has as many neurons as there are classes in hymenoptera_data.

# %%
model = models.resnet18(pretrained=False)

# Count total parameters
total_params = sum(p.numel() for p in model.parameters())
print(f"Total number of parameters in ResNet18: {total_params}")

# Check the last layer architecture
print(f"Last layer (fc): {model.fc}")
print(f"Number of output neurons in last layer: {model.fc.out_features}")
# Out:
# Total number of parameters in ResNet18: 11689512
# Last layer (fc): Linear(in_features=512, out_features=1000, bias=True)
# Number of output neurons in last layer: 1000
# /home/nicolas/Desktop/Temp/ML_S5_etudiants/.venv/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/nicolas/Desktop/Temp/ML_S5_etudiants/.venv/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
# Check if there's a softmax at the end
print(model)
print("\n# Note: ResNet18 does not include softmax in the forward method")
print("# The output is raw logits that will be combined with CrossEntropyLoss")
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )
#
# # Note: ResNet18 does not include softmax in the forward method
# # The output is raw logits that will be combined with CrossEntropyLoss

# %%
# Modification of the last layer of the classifier
def get_model(pretrained):
  model = models.resnet18(pretrained=pretrained)
  
  # Get the number of input features for the last layer
  num_ftrs = model.fc.in_features
  
  # Replace the last layer with a new one that has 2 output classes
  model.fc = nn.Linear(num_ftrs, 2)

  return model

model = get_model(False)

# %% [markdown]
# Now, let's define the negative log-likelihood as the cost function. To compute the log-likelihood, we could add a LogSoftmax layer to the ResNet. Another common way to do that is to use a loss function that includes *LogSoftmax*. In this regard, in PyTorch,  *nn.CrossEntropyLoss* combines both *LogSoftmax* and *NLLLoss*.

# %%
loss_fn = nn.CrossEntropyLoss()

# %% [markdown]
# Finally, let's define a function that incorporates the training loop:

# %%
def train_model(dataloaders, model, loss_fn, optimizer, num_epochs=1):
    since = time.time()

    for epoch in range(num_epochs):
        print(f'Epoch {epoch}/{num_epochs - 1}')
        print('-' * 10)

        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()
            else:
                model.eval()
                # Weights are not updated during the validation phase

            running_loss = 0.0
            running_corrects = 0

            for inputs, labels in dataloaders[phase]:
                optimizer.zero_grad()
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = loss_fn(outputs, labels)
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print(f'{phase} Loss: {epoch_loss:.4f} Acc: {100*epoch_acc:.2f}%')

    time_elapsed = time.time() - since
    print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')

    return model

# %% [markdown]
# **Exercise 7:** With the *train_model* function, train the ResNet over one epoch with mini-batches of 64 images.

# %%
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=64,
                                             shuffle=True, num_workers=2)
              for x in ['train', 'val']}

model = get_model(pretrained=False)
optimizer = torch.optim.SGD(model.parameters(), lr=0.001)

# Training over 1 epoch:
model = train_model(dataloaders, model, loss_fn, optimizer, num_epochs=1)
# Out:
# Epoch 0/0
# ----------
# train Loss: 0.7347 Acc: 49.59%
# val Loss: 0.6901 Acc: 52.29%
# Training complete in 0m 6s

# %% [markdown]
# ### **II.C.** Using a Graphics Card:

# %% [markdown]
# With more than 10 million parameters, training a ResNet18 on a CPU is much slower than the networks in Part I. \
# Let's repeat the same training using the GPU.

# %%
print(f'Runtime device :{device}')

# Load the model to the GPU:
model = model.to(device)
# Out:
# Runtime device :cuda:0

# %% [markdown]
# To load a torch.tensor on GPU, the syntax is the same:

# %%
x = torch.rand(2,1,4,4)
print("On CPU :\n",x)
x = x.to(device)
# Note: You can also use .cuda() without specifying the device name
# but this method is not recommended especially in a multi-gpu environment
print("On GPU :\n",x)

# bring back the x tensor to the CPU RAM:
x = x.to('cpu') # or x.cpu()
print('Back to CPU:\n',x)
# Out:
# On CPU :
#  tensor([[[[0.8339, 0.7749, 0.6936, 0.1531],
#           [0.1132, 0.7421, 0.4124, 0.2008],
#           [0.0994, 0.9215, 0.2880, 0.5654],
#           [0.6051, 0.2126, 0.8190, 0.8455]]],
#
#
#         [[[0.0731, 0.7424, 0.8894, 0.1059],
#           [0.0719, 0.6608, 0.8291, 0.5554],
#           [0.0158, 0.2548, 0.8364, 0.2074],
#           [0.9257, 0.9138, 0.6773, 0.9833]]]])
# On GPU :
#  tensor([[[[0.8339, 0.7749, 0.6936, 0.1531],
#           [0.1132, 0.7421, 0.4124, 0.2008],
#           [0.0994, 0.9215, 0.2880, 0.5654],
#           [0.6051, 0.2126, 0.8190, 0.8455]]],
#
#
#         [[[0.0731, 0.7424, 0.8894, 0.1059],
#           [0.0719, 0.6608, 0.8291, 0.5554],
#           [0.0158, 0.2548, 0.8364, 0.2074],
#           [0.9257, 0.9138, 0.6773, 0.9833]]]], device='cuda:0')
# Back to CPU:
#  tensor([[[[0.8339, 0.7749, 0.6936, 0.1531],
#           [0.1132, 0.7421, 0.4124, 0.2008],
#           [0.0994, 0.9215, 0.2880, 0.5654],
#           [0.6051, 0.2126, 0.8190, 0.8455]]],
#
#
#         [[[0.0731, 0.7424, 0.8894, 0.1059],
#           [0.0719, 0.6608, 0.8291, 0.5554],
#           [0.0158, 0.2548, 0.8364, 0.2074],
#           [0.9257, 0.9138, 0.6773, 0.9833]]]])

# %% [markdown]
# **Exercise 8:**
# - Complete the fonction *train_model_gpu* to train the model on GPU.
# - Compare the CPU and GPU training times.
# - What are the validation scores after 20 epochs on GPUs ?

# %%
def train_model_gpu(dataloaders, model, loss_fn, optimizer, num_epochs=1, device='cuda:0'):
    since = time.time()
    accs = []

    for epoch in range(num_epochs):
        print(f'Epoch {epoch}/{num_epochs - 1}')
        print('-' * 10)

        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()
            else:
                model.eval()

            running_loss = 0.0
            running_corrects = 0

            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)
                
                optimizer.zero_grad()
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = loss_fn(outputs, labels)
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]
            
            if phase == 'val':
                accs.append(epoch_acc.cpu().item())
            
            print(f'{phase} Loss: {epoch_loss:.4f} Acc: {100*epoch_acc:.2f}%')

    time_elapsed = time.time() - since
    print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')

    return model, accs

# %% [markdown]
# ### **II.D.** Impact of pretraining on performance:

# %% [markdown]
# Training is faster on a GPU, but it only leads to a very poor score, barely better than random chance. To improve performance, a simple idea is to use a network trained on a similar (or more general) task as a starting point for learning. Here, it works particularly well with networks trained on ImageNet, whose convolutional filters are already very rich.
#
# **Note:**
# This method is refered to as **fine-tuning** a **pretrained model**.

# %% [markdown]
# **Exercise 9:** Compare two ResNet18 trainings, one randomly initialized and the other pre-trained, using learning curves, over 25 epochs.

# %%
max_epochs = 25
# Learning "from scratch" (random weights) :
resnet_scratch = get_model(pretrained=False)
resnet_scratch = resnet_scratch.to(device)
optimizer_scratch = torch.optim.SGD(resnet_scratch.parameters(), lr=0.001)
resnet_scratch, accs_scratch = train_model_gpu(dataloaders, resnet_scratch, loss_fn, optimizer_scratch, num_epochs=max_epochs, device=device)
# Out:
# Epoch 0/24
# ----------
# train Loss: 0.6961 Acc: 51.64%
# val Loss: 0.6806 Acc: 60.13%
# Epoch 1/24
# ----------
# train Loss: 0.6878 Acc: 51.64%
# val Loss: 0.6994 Acc: 44.44%
# Epoch 2/24
# ----------
# train Loss: 0.6732 Acc: 60.66%
# val Loss: 0.6984 Acc: 47.71%
# Epoch 3/24
# ----------
# train Loss: 0.6889 Acc: 52.05%
# val Loss: 0.6998 Acc: 45.75%
# Epoch 4/24
# ----------
# train Loss: 0.6794 Acc: 58.20%
# val Loss: 0.6988 Acc: 48.37%
# Epoch 5/24
# ----------
# train Loss: 0.6697 Acc: 61.07%
# val Loss: 0.6960 Acc: 49.02%
# Epoch 6/24
# ----------
# train Loss: 0.6624 Acc: 63.11%
# val Loss: 0.6920 Acc: 52.94%
# Epoch 7/24
# ----------
# train Loss: 0.6689 Acc: 59.02%
# val Loss: 0.6833 Acc: 58.17%
# Epoch 8/24
# ----------
# train Loss: 0.6739 Acc: 59.43%
# val Loss: 0.6757 Acc: 60.13%
# Epoch 9/24
# ----------
# train Loss: 0.6596 Acc: 59.43%
# val Loss: 0.6679 Acc: 62.75%
# Epoch 10/24
# ----------
# train Loss: 0.6550 Acc: 63.11%
# val Loss: 0.6651 Acc: 64.71%
# Epoch 11/24
# ----------
# train Loss: 0.6589 Acc: 60.25%
# val Loss: 0.6625 Acc: 62.09%
# Epoch 12/24
# ----------
# train Loss: 0.6548 Acc: 59.84%
# val Loss: 0.6591 Acc: 60.78%
# Epoch 13/24
# ----------
# train Loss: 0.6546 Acc: 60.66%
# val Loss: 0.6585 Acc: 61.44%
# Epoch 14/24
# ----------
# train Loss: 0.6554 Acc: 60.25%
# val Loss: 0.6557 Acc: 60.13%
# Epoch 15/24
# ----------
# train Loss: 0.6560 Acc: 63.93%
# val Loss: 0.6540 Acc: 58.17%
# Epoch 16/24
# ----------
# train Loss: 0.6431 Acc: 66.39%
# val Loss: 0.6480 Acc: 59.48%
# Epoch 17/24
# ----------
# train Loss: 0.6338 Acc: 68.44%
# val Loss: 0.6457 Acc: 64.05%
# Epoch 18/24
# ----------
# train Loss: 0.6393 Acc: 62.70%
# val Loss: 0.6453 Acc: 60.13%
# Epoch 19/24
# ----------
# train Loss: 0.6283 Acc: 65.57%
# val Loss: 0.6431 Acc: 58.82%
# Epoch 20/24
# ----------
# train Loss: 0.6338 Acc: 66.39%
# val Loss: 0.6378 Acc: 62.09%
# Epoch 21/24
# ----------
# train Loss: 0.6400 Acc: 64.75%
# val Loss: 0.6349 Acc: 62.09%
# Epoch 22/24
# ----------
# train Loss: 0.6315 Acc: 64.34%
# val Loss: 0.6336 Acc: 60.78%
# Epoch 23/24
# ----------
# train Loss: 0.6279 Acc: 67.21%
# val Loss: 0.6299 Acc: 64.71%
# Epoch 24/24
# ----------
# train Loss: 0.6194 Acc: 64.34%
# val Loss: 0.6341 Acc: 62.09%
# Training complete in 0m 27s

# %%
# fine tuning a pretrained model:
resnet_ft = get_model(pretrained=True)
resnet_ft = resnet_ft.to(device)
optimizer_ft = torch.optim.SGD(resnet_ft.parameters(), lr=0.001)
resnet_ft, accs_ft = train_model_gpu(dataloaders, resnet_ft, loss_fn, optimizer_ft, num_epochs=max_epochs, device=device)
# Out:
# /home/nicolas/Desktop/Temp/ML_S5_etudiants/.venv/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /home/nicolas/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 176MB/s]
# Epoch 0/24
# ----------
# train Loss: 0.8795 Acc: 34.43%
# val Loss: 0.8276 Acc: 42.48%
# Epoch 1/24
# ----------
# train Loss: 0.8357 Acc: 36.07%
# val Loss: 0.7820 Acc: 45.75%
# Epoch 2/24
# ----------
# train Loss: 0.7763 Acc: 43.44%
# val Loss: 0.7413 Acc: 49.02%
# Epoch 3/24
# ----------
# train Loss: 0.7156 Acc: 52.87%
# val Loss: 0.7070 Acc: 53.59%
# Epoch 4/24
# ----------
# train Loss: 0.6989 Acc: 56.15%
# val Loss: 0.6784 Acc: 58.82%
# Epoch 5/24
# ----------
# train Loss: 0.6878 Acc: 58.61%
# val Loss: 0.6536 Acc: 62.09%
# Epoch 6/24
# ----------
# train Loss: 0.6466 Acc: 62.70%
# val Loss: 0.6262 Acc: 64.05%
# Epoch 7/24
# ----------
# train Loss: 0.6291 Acc: 63.11%
# val Loss: 0.6021 Acc: 64.71%
# Epoch 8/24
# ----------
# train Loss: 0.5936 Acc: 68.85%
# val Loss: 0.5791 Acc: 67.32%
# Epoch 9/24
# ----------
# train Loss: 0.5839 Acc: 70.90%
# val Loss: 0.5567 Acc: 69.28%
# Epoch 10/24
# ----------
# train Loss: 0.5651 Acc: 68.03%
# val Loss: 0.5356 Acc: 71.24%
# Epoch 11/24
# ----------
# train Loss: 0.5405 Acc: 75.41%
# val Loss: 0.5185 Acc: 73.86%
# Epoch 12/24
# ----------
# train Loss: 0.5081 Acc: 77.46%
# val Loss: 0.5045 Acc: 76.47%
# Epoch 13/24
# ----------
# train Loss: 0.5119 Acc: 79.51%
# val Loss: 0.4891 Acc: 77.78%
# Epoch 14/24
# ----------
# train Loss: 0.4882 Acc: 79.10%
# val Loss: 0.4743 Acc: 81.05%
# Epoch 15/24
# ----------
# train Loss: 0.4635 Acc: 81.56%
# val Loss: 0.4585 Acc: 82.35%
# Epoch 16/24
# ----------
# train Loss: 0.4607 Acc: 81.15%
# val Loss: 0.4458 Acc: 82.35%
# Epoch 17/24
# ----------
# train Loss: 0.4342 Acc: 84.84%
# val Loss: 0.4333 Acc: 84.97%
# Epoch 18/24
# ----------
# train Loss: 0.4492 Acc: 81.56%
# val Loss: 0.4222 Acc: 85.62%
# Epoch 19/24
# ----------
# train Loss: 0.4252 Acc: 83.61%
# val Loss: 0.4132 Acc: 86.27%
# Epoch 20/24
# ----------
# train Loss: 0.4125 Acc: 87.30%
# val Loss: 0.4029 Acc: 87.58%
# Epoch 21/24
# ----------
# train Loss: 0.4228 Acc: 83.20%
# val Loss: 0.3937 Acc: 88.24%
# Epoch 22/24
# ----------
# train Loss: 0.4156 Acc: 84.02%
# val Loss: 0.3851 Acc: 88.24%
# Epoch 23/24
# ----------
# train Loss: 0.3794 Acc: 87.70%
# val Loss: 0.3797 Acc: 88.24%
# Epoch 24/24
# ----------
# train Loss: 0.3968 Acc: 84.84%
# val Loss: 0.3723 Acc: 88.89%
# Training complete in 0m 26s

# %%
# Plot comparison: From scratch vs Fine-tuning
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(accs_scratch, 'r-', marker='o', label='From scratch', linewidth=2)
ax.plot(accs_ft, 'b-', marker='s', label='Pretrained (fine-tuning)', linewidth=2)
ax.set_xlabel('Epoch', fontsize=12)
ax.set_ylabel('Validation Accuracy', fontsize=12)
ax.set_title('Comparison: Training from scratch vs Fine-tuning', fontsize=14)
ax.legend(fontsize=11)
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# The fine-tuning approach has many variations that fit into the broader framework of **transfer learning**. Partial fine-tuning, as illustrated in the following exercise, is one of these variations.

# %% [markdown]
# **Exercise 10:** Instead of retraining all the weights, you can simply use the weights of the classifier. This is referred to as *freezing* the other weights during retraining. \
# Implement this approach and compare it with the previous ones.

# %%
# Fine tuning with frozen convolutional layers
resnet_frozen = get_model(pretrained=True)

# Freeze all layers except the classifier
for name, param in resnet_frozen.named_parameters():
    if 'fc' not in name:  # Freeze everything except fc layer
        param.requires_grad = False

resnet_frozen = resnet_frozen.to(device)

# Create optimizer with only unfrozen parameters
optimizer_frozen = torch.optim.SGD(filter(lambda p: p.requires_grad, resnet_frozen.parameters()), lr=0.001)
resnet_frozen, accs_frozen = train_model_gpu(dataloaders, resnet_frozen, loss_fn, optimizer_frozen, num_epochs=max_epochs, device=device)
# Out:
# Epoch 0/24
# ----------
# train Loss: 0.7984 Acc: 50.82%
# val Loss: 0.7041 Acc: 58.17%
# Epoch 1/24
# ----------
# train Loss: 0.6791 Acc: 55.33%
# val Loss: 0.6352 Acc: 64.05%
# Epoch 2/24
# ----------
# train Loss: 0.6527 Acc: 60.25%
# val Loss: 0.6008 Acc: 70.59%
# Epoch 3/24
# ----------
# train Loss: 0.6498 Acc: 64.34%
# val Loss: 0.5815 Acc: 71.24%
# Epoch 4/24
# ----------
# train Loss: 0.6175 Acc: 66.39%
# val Loss: 0.5668 Acc: 73.20%
# Epoch 5/24
# ----------
# train Loss: 0.6025 Acc: 66.39%
# val Loss: 0.5528 Acc: 73.86%
# Epoch 6/24
# ----------
# train Loss: 0.5694 Acc: 71.31%
# val Loss: 0.5404 Acc: 74.51%
# Epoch 7/24
# ----------
# train Loss: 0.5768 Acc: 71.72%
# val Loss: 0.5280 Acc: 75.82%
# Epoch 8/24
# ----------
# train Loss: 0.5454 Acc: 76.23%
# val Loss: 0.5180 Acc: 77.12%
# Epoch 9/24
# ----------
# train Loss: 0.5819 Acc: 71.31%
# val Loss: 0.5062 Acc: 77.78%
# Epoch 10/24
# ----------
# train Loss: 0.5438 Acc: 73.77%
# val Loss: 0.4947 Acc: 78.43%
# Epoch 11/24
# ----------
# train Loss: 0.5537 Acc: 70.90%
# val Loss: 0.4843 Acc: 79.08%
# Epoch 12/24
# ----------
# train Loss: 0.5120 Acc: 78.69%
# val Loss: 0.4772 Acc: 79.08%
# Epoch 13/24
# ----------
# train Loss: 0.5052 Acc: 81.97%
# val Loss: 0.4662 Acc: 79.08%
# Epoch 14/24
# ----------
# train Loss: 0.5090 Acc: 79.92%
# val Loss: 0.4591 Acc: 79.08%
# Epoch 15/24
# ----------
# train Loss: 0.4678 Acc: 84.43%
# val Loss: 0.4523 Acc: 80.39%
# Epoch 16/24
# ----------
# train Loss: 0.4879 Acc: 80.33%
# val Loss: 0.4450 Acc: 83.01%
# Epoch 17/24
# ----------
# train Loss: 0.4707 Acc: 81.15%
# val Loss: 0.4353 Acc: 84.31%
# Epoch 18/24
# ----------
# train Loss: 0.4432 Acc: 86.48%
# val Loss: 0.4288 Acc: 84.97%
# Epoch 19/24
# ----------
# train Loss: 0.4575 Acc: 82.79%
# val Loss: 0.4226 Acc: 85.62%
# Epoch 20/24
# ----------
# train Loss: 0.4785 Acc: 81.97%
# val Loss: 0.4150 Acc: 85.62%
# Epoch 21/24
# ----------
# train Loss: 0.4314 Acc: 87.30%
# val Loss: 0.4085 Acc: 86.27%
# Epoch 22/24
# ----------
# train Loss: 0.4362 Acc: 84.84%
# val Loss: 0.4014 Acc: 87.58%
# Epoch 23/24
# ----------
# train Loss: 0.4199 Acc: 88.93%
# val Loss: 0.3968 Acc: 86.93%
# Epoch 24/24
# ----------
# train Loss: 0.4148 Acc: 84.02%
# val Loss: 0.3919 Acc: 87.58%
# Training complete in 0m 22s

# %%
# Plot all three approaches for comparison
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(accs_scratch, 'r-', marker='o', label='From scratch', linewidth=2)
ax.plot(accs_ft, 'b-', marker='s', label='Fine-tuning all layers', linewidth=2)
ax.plot(accs_frozen, 'g-', marker='^', label='Frozen except classifier', linewidth=2)
ax.set_xlabel('Epoch', fontsize=12)
ax.set_ylabel('Validation Accuracy', fontsize=12)
ax.set_title('Comparison of Transfer Learning Approaches', fontsize=14)
ax.legend(fontsize=11)
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# In the end, for this small dataset, retraining the last layer performs just as well as global training. To conclude, let's make some predictions with the model on the validation dataset:

# %%
def visualize_model(model, num_images=10):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure(figsize=(25,num_images//5*5))

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//5, 5, images_so_far)
                ax.axis('off')
                imshow(inputs.cpu().data[j],ax,'Predicted: {}'.format(class_names[preds[j]]))

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
# Visualize predictions on 10 images from the validation set
visualize_model(resnet_frozen, num_images=10)
